# %%
import pandas as pd
import numpy as np

# %%
movies_url ="C:/Users/Mou/Desktop/School/Spring19/IS362/Week5/Movies.xlsx"
movies=pd.read_excel(movies_url)
movies.to_excel("C:\\Users\\Mou\\Desktop\\School\\Spring19\\IS362\\Week5\\Movies.xlsx",encoding="utf-8")
print(movies)
# Out:
#      FilmID                                    FilmName FilmReleaseDate  \
# 0         1                               Jurassic Park      1993-07-16
# 1         2                                  Spider-Man      2002-06-14
# 2         3                                   King Kong      2005-12-15
# 3         5                            Superman Returns      2006-07-16
# 4         6                                     Titanic      1998-01-23
# 5         7                               Evan Almighty      2007-08-03
# 6         8                                  Waterworld      1995-08-11
# 7         9                                Pearl Harbor      2001-06-01
# 8        10                                Transformers      2007-07-27
# 9        11   Harry Potter and the Order of the Phoenix      2007-07-12
# 10       12                                     Beowulf      2007-11-16
# 11       13                                   Bee Movie      2007-12-14
# ...

# %% [markdown]
# #  Replacing NULL with Blank,removing duplicate records

# %%
movies=movies.replace(np.nan, "",regex=True)
movies=movies.drop_duplicates()
print(movies)
# Out:
#      FilmID                                    FilmName       FilmReleaseDate  \
# 0         1                               Jurassic Park    742780800000000000
# 1         2                                  Spider-Man   1024012800000000000
# 2         3                                   King Kong   1134604800000000000
# 3         5                            Superman Returns   1153008000000000000
# 4         6                                     Titanic    885513600000000000
# 5         7                               Evan Almighty   1186099200000000000
# 6         8                                  Waterworld    808099200000000000
# 7         9                                Pearl Harbor    991353600000000000
# 8        10                                Transformers   1185494400000000000
# 9        11   Harry Potter and the Order of the Phoenix   1184198400000000000
# 10       12                                     Beowulf   1195171200000000000
# ...

# %% [markdown]
# # Missing Data

# %%
movies.isnull().sum(axis=0)
# Out:
# FilmID                    0
# FilmName                  0
# FilmReleaseDate           1
# FilmDirectorID            1
# FilmLanguageID            1
# FilmCountryID             1
# FilmStudioID              2
# FilmSynopsis              1
# FilmRunTimeMinutes        1
# FilmCertificateID       101
# FilmBudgetDollars         3
# FilmBoxOfficeDollars      9
# FilmOscarNominations      1
# FilmOscarWins             1
# dtype: int64

# %%
movies[movies['FilmReleaseDate'].isnull()]
# Out:
#      FilmID FilmName FilmReleaseDate  FilmDirectorID  FilmLanguageID  \
# 260     400       sf             NaT             NaN             NaN
#
#      FilmCountryID  FilmStudioID FilmSynopsis  FilmRunTimeMinutes  \
# 260            NaN           NaN          NaN                 NaN
#
#      FilmCertificateID  FilmBudgetDollars  FilmBoxOfficeDollars  \
# 260                NaN                NaN                   NaN
#
#      FilmOscarNominations  FilmOscarWins
# 260                   NaN            NaN

# %%
movies[movies['FilmStudioID'].isnull()]
# Out:
#      FilmID  FilmName FilmReleaseDate  FilmDirectorID  FilmLanguageID  \
# 224     227  Das Boot      1982-02-10            25.0             4.0
# 260     400        sf             NaT             NaN             NaN
#
#      FilmCountryID  FilmStudioID  \
# 224          257.0           NaN
# 260            NaN           NaN
#
#                                           FilmSynopsis  FilmRunTimeMinutes  \
# 224  The claustrophobic world of a WWII German U-bo...               149.0
# 260                                                NaN                 NaN
#
#      FilmCertificateID  FilmBudgetDollars  FilmBoxOfficeDollars  \
# 224                NaN         12000000.0            84970337.0
# 260                NaN                NaN                   NaN
#
#      FilmOscarNominations  FilmOscarWins
# 224                   6.0            0.0
# 260                   NaN            NaN

# %%
movies[movies['FilmCertificateID'].isnull()]
# Out:
#      FilmID                                           FilmName  \
# 27       29                  Final Fantasy: The Spirits Within
# 28       30                                         Miami Vice
# 154     156                                    Licence to Kill
# 155     157                               The Living Daylights
# 156     158                                           Sin City
# 157     159                                           Serenity
# 159     161                              Never Say Never Again
# 161     163                                          Rush Hour
# 162     164                                    Lethal Weapon 3
# 163     165         Star Wars: Episode IV - Return of the Jedi
# 164     166                              A History of Violence
# 165     167                                          Moonraker
# 166     168                                         Get Shorty
# 167     169  The Assassination of Jesse James by the Coward...
# ...

# %%
movies[movies['FilmBudgetDollars'].isnull()]
# Out:
#      FilmID                     FilmName FilmReleaseDate  FilmDirectorID  \
# 242     246  Around the World in 80 Days      1956-10-17           117.0
# 256     262                    Kagemusha      1980-10-06           122.0
# 260     400                           sf             NaT             NaN
#
#      FilmLanguageID  FilmCountryID  FilmStudioID  \
# 242             1.0          241.0          22.0
# 256             6.0          118.0          38.0
# 260             NaN            NaN           NaN
#
#                                           FilmSynopsis  FilmRunTimeMinutes  \
# 242  Adaptation of Jules Verne's novel about a Vict...               167.0
# 256  When a powerful warlord in medieval Japan dies...               179.0
# 260                                                NaN                 NaN
#
#      FilmCertificateID  FilmBudgetDollars  FilmBoxOfficeDollars  \
# 242                NaN                NaN                   NaN
# ...

# %%
movies[movies['FilmBoxOfficeDollars'].isnull()]
# Out:
#      FilmID                     FilmName FilmReleaseDate  FilmDirectorID  \
# 110     112      The Long Kiss Goodnight      1996-11-29            69.0
# 113     115                   Fight Club      1999-11-12            70.0
# 142     144             Shanghai Knights      2003-04-04            81.0
# 149     151     The Last of the Mohicans      1992-11-06            34.0
# 242     246  Around the World in 80 Days      1956-10-17           117.0
# 256     262                    Kagemusha      1980-10-06           122.0
# 257     263                          Ran      1985-06-01           122.0
# 259     265           Once Were Warriors      1995-04-14            29.0
# 260     400                           sf             NaT             NaN
#
#      FilmLanguageID  FilmCountryID  FilmStudioID  \
# 110             1.0          241.0          14.0
# 113             1.0          241.0           4.0
# 142             1.0          241.0           7.0
# ...

# %%
movies.count()
# Out:
# FilmID                  261
# FilmName                261
# FilmReleaseDate         260
# FilmDirectorID          260
# FilmLanguageID          260
# FilmCountryID           260
# FilmStudioID            259
# FilmSynopsis            260
# FilmRunTimeMinutes      260
# FilmCertificateID       160
# FilmBudgetDollars       258
# FilmBoxOfficeDollars    252
# FilmOscarNominations    260
# FilmOscarWins           260
# dtype: int64

# %%
movies['FilmOscarNominations'].value_counts()
# Out:
# 0.0     119
# 1.0      39
# 2.0      26
# 3.0      22
# 4.0      15
# 7.0       6
# 8.0       6
# 5.0       6
# 6.0       5
# 10.0      5
# 11.0      4
# 12.0      3
# 9.0       2
# 13.0      1
# 14.0      1
# Name: FilmOscarNominations, dtype: int64

# %%
movies['FilmOscarNominations'].fillna(value='0',inplace=True)
movies['FilmOscarNominations'].value_counts(dropna=False)
# Out:
# 0.0     119
# 1.0      39
# 2.0      26
# 3.0      22
# 4.0      15
# 8.0       6
# 7.0       6
# 5.0       6
# 10.0      5
# 6.0       5
# 11.0      4
# 12.0      3
# 9.0       2
# 0         1
# 14.0      1
# 13.0      1
# Name: FilmOscarNominations, dtype: int64

# %% [markdown]
# # Sorting

# %%
movies['FilmRunTimeMinutes'].sort_values()
# Out:
# 199     84.0
# 98      87.0
# 23      88.0
# 141     90.0
# 74      90.0
# 11      90.0
# 73      91.0
# 45      92.0
# 102     92.0
# 103     93.0
# 239     93.0
# 218     94.0
# 187     94.0
# 5       95.0
# 164     96.0
# 121     96.0
# 161     97.0
# 236     98.0
# 75      98.0
# 259     99.0
# 245     99.0
# 251     99.0
# 202     99.0
# 253    100.0
# 255    100.0
# 125    100.0
# 124    101.0
# 84     101.0
# 179    101.0
# 13     101.0
#        ...
# 66     155.0
# 220    156.0
# 16     157.0
# 64     157.0
# 56     157.0
# 257    160.0
# 167    160.0
# 63     161.0
# 15     163.0
# 90     164.0
# 68     167.0
# 242    167.0
# 12     168.0
# 55     170.0
# 112    170.0
# 188    170.0
# 99     177.0
# 57     178.0
# 139    178.0
# 72     179.0
# 256    179.0
# 197    180.0
# 7      183.0
# 2      187.0
# 192    188.0
# 254    190.0
# 4      194.0
# 186    195.0
# 71     201.0
# 260      NaN
# Name: FilmRunTimeMinutes, Length: 261, dtype: float64

# %%
movies['FilmRunTimeMinutes'].sort_values(ascending=False)
# Out:
# 71     201.0
# 186    195.0
# 4      194.0
# 254    190.0
# 192    188.0
# 2      187.0
# 7      183.0
# 197    180.0
# 256    179.0
# 72     179.0
# 139    178.0
# 57     178.0
# 99     177.0
# 188    170.0
# 112    170.0
# 55     170.0
# 12     168.0
# 242    167.0
# 68     167.0
# 90     164.0
# 15     163.0
# 63     161.0
# 167    160.0
# 257    160.0
# 56     157.0
# 64     157.0
# 16     157.0
# 220    156.0
# 66     155.0
# 233    154.0
#        ...
# 179    101.0
# 84     101.0
# 124    101.0
# 125    100.0
# 255    100.0
# 253    100.0
# 202     99.0
# 251     99.0
# 245     99.0
# 259     99.0
# 75      98.0
# 236     98.0
# 161     97.0
# 121     96.0
# 164     96.0
# 5       95.0
# 187     94.0
# 218     94.0
# 239     93.0
# 103     93.0
# 102     92.0
# 45      92.0
# 73      91.0
# 11      90.0
# 74      90.0
# 141     90.0
# 23      88.0
# 98      87.0
# 199     84.0
# 260      NaN
# Name: FilmRunTimeMinutes, Length: 261, dtype: float64

# %%
movies.sort_values(['FilmRunTimeMinutes','FilmCertificateID'])
# Out:
#      FilmID                                           FilmName  \
# 199     202  Borat: Cultural Learnings of America for Make ...
# 98      100                                 The Simpsons Movie
# 23       25                                     Men in Black 2
# 11       13                                          Bee Movie
# 141     143                                              Shrek
# 74       76                                        Rush Hour 2
# 73       75                                        Rush Hour 3
# 45       47                                     Monsters, Inc.
# 102     104                                    Shrek the Third
# 103     105                                            Shrek 2
# 239     243                          Good Night, and Good Luck
# 187     189              Anchorman: The Legend of Ron Burgundy
# 218     221                                      Trainspotting
# 5         7                                      Evan Almighty
# ...

# %% [markdown]
# # Applying multiple filter criteria to a pandas DataFrame

# %%
movies[movies['FilmRunTimeMinutes'] >= 100.0]
# Out:
#      FilmID                                         FilmName FilmReleaseDate  \
# 0         1                                    Jurassic Park      1993-07-16
# 1         2                                       Spider-Man      2002-06-14
# 2         3                                        King Kong      2005-12-15
# 3         5                                 Superman Returns      2006-07-16
# 4         6                                          Titanic      1998-01-23
# 6         8                                       Waterworld      1995-08-11
# 7         9                                     Pearl Harbor      2001-06-01
# 8        10                                     Transformers      2007-07-27
# 9        11        Harry Potter and the Order of the Phoenix      2007-07-12
# 10       12                                          Beowulf      2007-11-16
# 12       14         Pirates of the Caribbean: At World's End      2007-05-24
# ...

# %%
movies[(movies['FilmRunTimeMinutes'] > 100.0) & (movies['FilmOscarNominations']==5)]
# Out:
#      FilmID                                           FilmName  \
# 14       16                                        Ratatouille
# 38       40  Pirates of the Caribbean: Curse of the Black P...
# 65       67                                      Blood Diamond
# 76       78                                       The Departed
# 90       92                                             Munich
# 228     231                                             Amelie
#
#     FilmReleaseDate  FilmDirectorID  FilmLanguageID  FilmCountryID  \
# 14       2007-10-12            24.0             1.0          241.0
# 38       2003-08-08            22.0             1.0          241.0
# 65       2007-01-26            43.0             1.0          241.0
# 76       2006-10-06             9.0             1.0          241.0
# 90       2006-01-27             4.0             1.0          241.0
# 228      2001-10-05           111.0             3.0           79.0
#
# ...

# %%
movies[(movies['FilmRunTimeMinutes'] > 100.0) | (movies['FilmOscarNominations']==5)]
# Out:
#      FilmID                                         FilmName FilmReleaseDate  \
# 0         1                                    Jurassic Park      1993-07-16
# 1         2                                       Spider-Man      2002-06-14
# 2         3                                        King Kong      2005-12-15
# 3         5                                 Superman Returns      2006-07-16
# 4         6                                          Titanic      1998-01-23
# 6         8                                       Waterworld      1995-08-11
# 7         9                                     Pearl Harbor      2001-06-01
# 8        10                                     Transformers      2007-07-27
# 9        11        Harry Potter and the Order of the Phoenix      2007-07-12
# 10       12                                          Beowulf      2007-11-16
# 12       14         Pirates of the Caribbean: At World's End      2007-05-24
# ...

# %%
movies[(movies['FilmRunTimeMinutes'] > 100.0) | (movies['FilmOscarNominations']==5) |(movies['FilmOscarWins']==2)]
# Out:
#      FilmID                                         FilmName FilmReleaseDate  \
# 0         1                                    Jurassic Park      1993-07-16
# 1         2                                       Spider-Man      2002-06-14
# 2         3                                        King Kong      2005-12-15
# 3         5                                 Superman Returns      2006-07-16
# 4         6                                          Titanic      1998-01-23
# 6         8                                       Waterworld      1995-08-11
# 7         9                                     Pearl Harbor      2001-06-01
# 8        10                                     Transformers      2007-07-27
# 9        11        Harry Potter and the Order of the Phoenix      2007-07-12
# 10       12                                          Beowulf      2007-11-16
# 12       14         Pirates of the Caribbean: At World's End      2007-05-24
# ...

# %% [markdown]
# # Grouping Data

# %%
movies['FilmBudgetDollars'].mean()
# Out:
# 66588608.84108527

# %%
movies.groupby('FilmOscarNominations').size()
# Out:
# FilmOscarNominations
# 0.0     119
# 1.0      39
# 2.0      26
# 3.0      22
# 4.0      15
# 5.0       6
# 6.0       5
# 7.0       6
# 8.0       6
# 9.0       2
# 10.0      5
# 11.0      4
# 12.0      3
# 13.0      1
# 14.0      1
# 0         1
# dtype: int64

# %%
movies.groupby('FilmOscarNominations').FilmBudgetDollars.mean()
# Out:
# FilmOscarNominations
# 0.0     6.871061e+07
# 1.0     6.297559e+07
# 2.0     5.564000e+07
# 3.0     7.909091e+07
# 4.0     8.186667e+07
# 5.0     9.172500e+07
# 6.0     4.360000e+07
# 7.0     2.041667e+07
# 8.0     2.898000e+07
# 9.0     3.775000e+07
# 10.0    6.600000e+07
# 11.0    7.275000e+07
# 12.0    4.900000e+07
# 13.0    1.090000e+08
# 14.0    2.000000e+08
# 0                NaN
# Name: FilmBudgetDollars, dtype: float64

# %%
movies.groupby('FilmOscarNominations').FilmBudgetDollars.max()
# Out:
# FilmOscarNominations
# 0.0     258000000.0
# 1.0     204000000.0
# 2.0     150000000.0
# 3.0     200000000.0
# 4.0     207000000.0
# 5.0     150000000.0
# 6.0      94000000.0
# 7.0      44000000.0
# 8.0      78000000.0
# 9.0      65000000.0
# 10.0    135000000.0
# 11.0    110000000.0
# 12.0    103000000.0
# 13.0    109000000.0
# 14.0    200000000.0
# 0               NaN
# Name: FilmBudgetDollars, dtype: float64

# %%
movies.groupby('FilmOscarNominations').FilmBudgetDollars.agg(['count','min','max','mean'])
# Out:
#                       count          min          max          mean
# FilmOscarNominations
# 0.0                     119     670000.0  258000000.0  6.871061e+07
# 1.0                      39      65000.0  204000000.0  6.297559e+07
# 2.0                      25     500000.0  150000000.0  5.564000e+07
# 3.0                      22   14000000.0  200000000.0  7.909091e+07
# 4.0                      15   12000000.0  207000000.0  8.186667e+07
# 5.0                       6   10350000.0  150000000.0  9.172500e+07
# 6.0                       5    7000000.0   94000000.0  4.360000e+07
# 7.0                       6    7000000.0   44000000.0  2.041667e+07
# 8.0                       5   13900000.0   78000000.0  2.898000e+07
# 9.0                       2   10500000.0   65000000.0  3.775000e+07
# 10.0                      5   11000000.0  135000000.0  6.600000e+07
# 11.0                      4   22000000.0  110000000.0  7.275000e+07
# ...

# %%
# %matplotlib inline

# %%
movies.groupby('FilmOscarWins').mean().plot(kind='bar')
